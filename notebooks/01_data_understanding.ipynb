# %%
import sys
print(sys.executable)
# Out:
# c:\Users\anshi\OneDrive\Desktop\StartupAtlas\StartupAtlas\venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 3.0.3
# 2.4.6

# %%
df = pd.read_csv(
    "../data/raw/investments_VC.csv",
    encoding="latin1"
)

# %%
df.shape
# Out:
# (54294, 39)

# %%
df.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', ' market ',
#        ' funding_total_usd ', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'market',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H'],
#       dtype='str')

# %%
df['status'].value_counts()
# Out:
# status
# operating    41829
# acquired      3692
# closed        2603
# Name: count, dtype: int64

# %%
df[['funding_total_usd', 'funding_rounds']].describe()
# Out:
#        funding_rounds
# count    49438.000000
# mean         1.696205
# std          1.294213
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         18.000000

# %%
df['market'].value_counts().head(20)
# Out:
# market
# Software                4620
# Biotechnology           3688
# Mobile                  1983
# E-Commerce              1805
# Curated Web             1655
# Enterprise Software     1280
# Health Care             1207
# Clean Technology        1200
# Games                   1182
# Hardware + Software     1081
# Advertising             1064
# Health and Wellness      920
# Social Media             876
# Finance                  867
# Education                863
# Manufacturing            744
# Analytics                617
# Security                 526
# Semiconductors           507
# Consulting               483
# Name: count, dtype: int64

# %%
df['funding_total_usd'] = pd.to_numeric(
    df['funding_total_usd'],
    errors='coerce'
)

top_funding = (
    df.groupby('market')['funding_total_usd']
      .sum()
      .sort_values(ascending=False)
      .head(20)
)

top_funding
# Out:
# market
# Medical                  1800.0
# Consulting               1600.0
# Entertainment            1117.0
# Internet of Things        929.0
# E-Commerce                900.0
# Teenagers                 890.0
# Software                  612.0
# Games                     600.0
# Automotive                500.0
# Hospitality               500.0
# Fashion                   410.0
# Sports                    400.0
# Transportation            350.0
# Oil & Gas                 300.0
# Twitter Applications      291.0
# Sales and Marketing       118.0
# Farming                   100.0
# Marketplaces               60.0
# Design                      1.0
# Advertising Networks        0.0
# Name: funding_total_usd, dtype: float64

# %%
df['funding_total_usd'].head(10)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: funding_total_usd, dtype: float64

# %%
df['funding_total_usd'].dtype
# Out:
# dtype('float64')

# %%
df2 = pd.read_csv(
    "../data/raw/investments_VC.csv",
    encoding="latin1"
)

# %%
df2[' funding_total_usd '].head(20)
# Out:
# 0      17,50,000
# 1      40,00,000
# 2         40,000
# 3      15,00,000
# 4         60,000
# 5      70,00,000
# 6      49,12,393
# 7      20,00,000
# 8            -
# 9         41,250
# 10        40,000
# 11           -
# 12           -
# 13     17,50,000
# 14           -
# 15     44,00,000
# 16     20,50,000
# 17        40,000
# 18      5,00,000
# 19           -
# Name:  funding_total_usd , dtype: str

# %%
df2[' funding_total_usd '].sample(10)
# Out:
# 41509     4,77,78,903
# 4760              -
# 2561           35,000
# 30875             -
# 28773     1,66,48,351
# 48208       37,50,000
# 1627        25,00,000
# 49631              NaN
# 6911      9,20,00,000
# 13556     3,00,00,000
# Name:  funding_total_usd , dtype: str

# %%
df['funding_total_usd'] = (
    df['funding_total_usd']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('-', '', regex=False)
    .str.strip()
)

df['funding_total_usd'] = pd.to_numeric(
    df['funding_total_usd'],
    errors='coerce'
)

# %%
df['funding_total_usd'].head(20)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: funding_total_usd, dtype: float64

# %%
df = pd.read_csv(
    "../data/raw/investments_VC.csv",
    encoding="latin1"
)

df.columns = df.columns.str.strip()

# %%
df['funding_total_usd'].head(20)
# Out:
# 0      17,50,000
# 1      40,00,000
# 2         40,000
# 3      15,00,000
# 4         60,000
# 5      70,00,000
# 6      49,12,393
# 7      20,00,000
# 8            -
# 9         41,250
# 10        40,000
# 11           -
# 12           -
# 13     17,50,000
# 14           -
# 15     44,00,000
# 16     20,50,000
# 17        40,000
# 18      5,00,000
# 19           -
# Name: funding_total_usd, dtype: str

# %%
df['funding_total_usd'] = (
    df['funding_total_usd']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('-', '', regex=False)
    .str.strip()
)

# %%
df['funding_total_usd'].head(20)
# Out:
# 0     1750000
# 1     4000000
# 2       40000
# 3     1500000
# 4       60000
# 5     7000000
# 6     4912393
# 7     2000000
# 8
# 9       41250
# 10      40000
# 11
# 12
# 13    1750000
# 14
# 15    4400000
# 16    2050000
# 17      40000
# 18     500000
# 19
# Name: funding_total_usd, dtype: str

# %%
df['funding_total_usd'] = pd.to_numeric(
    df['funding_total_usd'],
    errors='coerce'
)

# %%
df['funding_total_usd'].head(20)
# Out:
# 0     1750000.0
# 1     4000000.0
# 2       40000.0
# 3     1500000.0
# 4       60000.0
# 5     7000000.0
# 6     4912393.0
# 7     2000000.0
# 8           NaN
# 9       41250.0
# 10      40000.0
# 11          NaN
# 12          NaN
# 13    1750000.0
# 14          NaN
# 15    4400000.0
# 16    2050000.0
# 17      40000.0
# 18     500000.0
# 19          NaN
# Name: funding_total_usd, dtype: float64

# %%
df['funding_total_usd'].describe()
# Out:
# count    4.090700e+04
# mean     1.591253e+07
# std      1.686788e+08
# min      1.000000e+00
# 25%      3.500000e+05
# 50%      2.000000e+06
# 75%      1.000000e+07
# max      3.007950e+10
# Name: funding_total_usd, dtype: float64

# %%
top_funding = (
    df.groupby('market')['funding_total_usd']
      .sum()
      .sort_values(ascending=False)
      .head(20)
)

top_funding
# Out:
# market
# Biotechnology           7.337295e+10
# Mobile                  4.947011e+10
# Software                4.222348e+10
# Clean Technology        3.761994e+10
# Health Care             2.946608e+10
# E-Commerce              2.240839e+10
# Enterprise Software     1.929719e+10
# Finance                 1.737230e+10
# Hardware + Software     1.281293e+10
# Advertising             1.266066e+10
# Semiconductors          1.234175e+10
# Health and Wellness     1.220653e+10
# Web Hosting             1.072166e+10
# Technology              1.010378e+10
# Curated Web             9.587998e+09
# Internet                9.369624e+09
# Games                   9.356133e+09
# Manufacturing           8.731243e+09
# Analytics               7.986746e+09
# Security                7.208829e+09
# Name: funding_total_usd, dtype: float64

# %%
import matplotlib.pyplot as plt

top_funding.plot(kind='bar')

plt.title("Top Markets by Total Funding")
plt.xlabel("Market")
plt.ylabel("Funding")
plt.xticks(rotation=45)

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

top_funding.plot(kind='bar')

plt.title("Top Startup Markets by Total Funding")
plt.xlabel("Market")
plt.ylabel("Funding (USD)")
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
import plotly.express as px

fig = px.bar(
    x=top_funding.index,
    y=top_funding.values,
    title="Top Startup Markets by Total Funding"
)

fig.show()

# %%
df.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# state_code           24133
# founded_quarter      15812
# founded_month        15812
# founded_year         15812
# founded_at           15740
# funding_total_usd    13387
# city                 10972
# region               10129
# country_code         10129
# market                8824
# category_list         8817
# homepage_url          8305
# status                6170
# name                  4857
# permalink             4856
# dtype: int64
